# %% [markdown]
# <a href="https://colab.research.google.com/github/nathanzhou17/CainCamera/blob/master/GettingStartedOpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-953d96ac-0fd0-424d-a3bb-1790e596a971" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-953d96ac-0fd0-424d-a3bb-1790e596a971">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image(filename='eX0v1eS3Re_1600.jpg')

# %%
Image(filename='eX0v1eS3Re_1600.jpg')

# %%
cb_img = cv2.imread("eX0v1eS3Re_1600.jpg",0)
print(cb_img)
# Out:
# [[189 189 189 ... 162 162 161]
#  [188 188 189 ... 163 162 162]
#  [188 188 188 ... 163 163 163]
#  ...
#  [104 105 106 ... 118 118 118]
#  [105 105 106 ... 118 118 118]
#  [105 105 105 ... 118 118 118]]

# %%
print("Image size is ", cb_img.shape)
print("Data type of image is ",cb_img.dtype)
# Out:
# Image size is  (1200, 1600)
# Data type of image is  uint8

# %%
plt.imshow(cb_img)

# %%
plt.imshow(cb_img, cmap='gray')

# %%
#color images
uploaded=files.upload()
# Out:
#      <input type="file" id="files-d683f4e0-c1cc-4810-b2b3-dc980475d869" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d683f4e0-c1cc-4810-b2b3-dc980475d869">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image("coca-cola.jpg")

# %%
coke_img = cv2.imread("eX0v1eS3Re_1600.jpg",1)
print("Image size is ", coke_img.shape)
print("Data type of image is ",coke_img.dtype)
print(" ")
# Out:
# Image size is  (1200, 1600, 3)
# Data type of image is  uint8

# %%
mask = np.zeros_like(coke_img)
mask[100:600, 600:1000] = 1
damaged_img = coke_img.copy()
damaged_img[mask == 1] = 0

plt.imshow(damaged_img)

# %%
def func(img, masj, num_iter=200,lamb=0.25):
  img = img.astype(np.float32)
  mask = mask.astype(bool)
  for _ in range (num_iter):
    north = np.roll(img, -1, axis = 0)
    south = np.roll(img, 1, axis = 0)
    east = np.roll(img, -1, axis = 1)
    west = np.roll(img, 1, axis = 1)
    l = (north + south + east + west -4 * img)
    update = lamb * l

    img[mask] = img[mask] + update[mask]
  return np.clip(0, 255).astype(np.uint8)

inpaint = func(damaged_img, mask)

plt.imshow(inpaint)

# %%
plt.imshow(coke_img)

# %% [markdown]
# It is important to note that openCV stores the images in BGR format and matplotlib uses RGB format.
# so we can change the image to original image by reversing using the following syntax

# %%
coke_img_channels_reversed = coke_img[:, :, ::-1]
plt.imshow(coke_img_channels_reversed)

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-ac411e95-a7a8-4203-a567-bd08db3b3352" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ac411e95-a7a8-4203-a567-bd08db3b3352">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img_NZ_bgr = cv2.imread("new_zealand_lake.jpg")
b,g,r = cv2.split(img_NZ_bgr)
#show the channels
plt.figure(figsize=[20,5])
plt.subplot(141);plt.imshow(r,cmap='gray');plt.title('Red channel')
plt.subplot(142);plt.imshow(g,cmap='gray');plt.title('Green channel')
plt.subplot(143);plt.imshow(b,cmap='gray');plt.title('Blue channel')
#Merge the individual channel into BGR image
imgMerged = cv2.merge((b,g,r))
#show the merged output
plt.subplot(144);plt.imshow(imgMerged[:,:,::-1]);plt.title("Merged output")
# Out:
# Text(0.5, 1.0, 'Merged output')

# %%
plt.imshow(img_NZ_bgr)

# %%
#changing from BGR to RGB
img_NZ_rgb = cv2.cvtColor(img_NZ_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(img_NZ_rgb)

# %%
#changing to HSV color space
img_hsv = cv2.cvtColor(img_NZ_bgr, cv2.COLOR_BGR2HSV)
h,s,v = cv2.split(img_hsv)

#showing hue saturation and value channels seperately
plt.figure(figsize=[20,5])
plt.subplot(141);plt.imshow(h, cmap='gray');plt.title('H channel');
plt.subplot(142);plt.imshow(s, cmap='gray');plt.title('S channel');
plt.subplot(143);plt.imshow(v, cmap='gray');plt.title('V channel');
plt.subplot(144);plt.imshow(img_NZ_rgb);plt.title('Original');

# %%
#Modifying individual channel
h_new = h+10
img_NZ_merged = cv2.merge((h_new,s,v))
img_NZ_rgbm = cv2.cvtColor(img_NZ_merged, cv2.COLOR_HSV2RGB)

#showing the channels
plt.figure(figsize=[20,5])
plt.subplot(141);plt.imshow(h, cmap='gray');plt.title('H channel');
plt.subplot(142);plt.imshow(s, cmap='gray');plt.title('S channel');
plt.subplot(143);plt.imshow(v, cmap='gray');plt.title('V channel');
plt.subplot(144);plt.imshow(img_NZ_rgbm);plt.title('Modified');
# Out:
# <class 'matplotlib.image.AxesImage'>

# %%
#saving the image
cv2.imwrite('NZ_lake_saved.png', img_NZ_bgr)
Image(filename='NZ_lake_saved.png')

# %%
#read the same image and check shape for color and gray scale
img_NZ_bgr = cv2.imread('NZ_lake_saved.png', cv2.IMREAD_COLOR)
print("img_NZ_bgr shape is :",img_NZ_bgr.shape)

#read the image as Grayscaled
img_NZ_gry = cv2.imread("NZ_lake_saved.png", cv2.IMREAD_GRAYSCALE)
print("img_NZ_gry shape is :",img_NZ_gry.shape)
# Out:
# img_NZ_bgr shape is : (300, 533, 3)
# img_NZ_gry shape is : (300, 533)
